# %%
import pandas as pd 
df=pd.read_csv(r'healthcare_dataset.csv')
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
df.head(20)
# Out:
#                    Name  Age  Gender Blood Type Medical Condition  \
# 0         Bobby JacksOn   30    Male         B-            Cancer
# 1          LesLie TErRy   62    Male         A+           Obesity
# 2           DaNnY sMitH   76  Female         A-           Obesity
# 3          andrEw waTtS   28  Female         O+          Diabetes
# 4         adrIENNE bEll   43  Female        AB+            Cancer
# 5         EMILY JOHNSOn   36    Male         A+            Asthma
# 6        edwArD EDWaRDs   21  Female        AB-          Diabetes
# 7    CHrisTInA MARtinez   20  Female         A+            Cancer
# 8       JASmINe aGuIlaR   82    Male        AB+            Asthma
# 9      ChRISTopher BerG   58  Female        AB-            Cancer
# 10     mIchElLe daniELs   72    Male         O+            Cancer
# 11       aaRon MARtiNeZ   38  Female         A-      Hypertension
# 12        connOR HANsEn   75  Female         A+          Diabetes
# ...

# %%
df.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  55500.000000    55500.000000  55500.000000
# mean      51.539459    25539.316097    301.134829
# std       19.602454    14211.454431    115.243069
# min       13.000000    -2008.492140    101.000000
# 25%       35.000000    13241.224652    202.000000
# 50%       52.000000    25538.069376    302.000000
# 75%       68.000000    37820.508436    401.000000
# max       89.000000    52764.276736    500.000000

# %%
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %% [markdown]
# #### Detecting outliers

# %%
#1.detect and remove outliers
import pandas as pd
import numpy as np
from scipy import stats
#
def detect_outliers_zscore(df):
    def detect_outliers_zscore(df):
    # Select only numerical columns for outlier detection
     numeric_df= df.select_dtypes(include=[np.number])
    
    # Calculate the Z-scores
     z_scores = np.abs(stats.zscore(numeric_df))
    
    # Define a threshold for identifying outliers
     threshold = 3
    
    # Find outliers
     outliers = (z_scores > threshold).any(axis=1)  # Check if any column has a Z-score above the threshold
    
    # Return the original rows that contain outliers
     return df[outliers]
outliers_df = detect_outliers_zscore(df)
print(outliers_df)
# Out:
# None

# %% [markdown]
# #### Visualizations to compare patient age distribution across different diseases

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#Box plot
plt.figure(figsize=(8, 6))
sns.boxplot(x='Medical Condition',y='Age',data=df)
plt.title('Boxplot of a medical Condition among Age')
plt.xlabel('Medical Condition')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# #### Violin Plot of medical conditions based on age

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x='Medical Condition', y='Age', data=df)
plt.title('Age Distribution by Disease')
plt.xlabel('Medical Condition')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# #### Histogram based on medical condition and age

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='Medical Condition', hue='Age', multiple="stack", bins=5, kde=True)
plt.title('Age Distribution by Disease')
plt.xlabel('Medical Condition')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# #### Indentifying most common medical conditions based on gender or age groups

# %%
common_cndn_gender=df.groupby('Gender')['Medical Condition'].value_counts()
common_cndn_gender
# Out:
# Gender  Medical Condition
# Female  Arthritis            4686
#         Diabetes             4651
#         Obesity              4622
#         Hypertension         4612
#         Cancer               4602
#         Asthma               4553
# Male    Diabetes             4653
#         Hypertension         4633
#         Asthma               4632
#         Cancer               4625
#         Arthritis            4622
#         Obesity              4609
# Name: count, dtype: int64

# %%
# Group by gender and medical condition, then count occurrences
common_conditions_by_gender = df.groupby('Gender')['Medical Condition'].value_counts()

# Convert to a DataFrame and reset the index to make it easier to read
common_conditions_by_gender_df = common_conditions_by_gender.reset_index(name='Count')

# Sort the result to get the most common condition for each gender
most_common_conditions_by_gender = common_conditions_by_gender_df.groupby('Gender').apply(lambda x: x.nlargest(5, 'Count'))

print(most_common_conditions_by_gender)
# Out:
#            Gender Medical Condition  Count
# Gender
# Female 0   Female         Arthritis   4686
#        1   Female          Diabetes   4651
#        2   Female           Obesity   4622
#        3   Female      Hypertension   4612
#        4   Female            Cancer   4602
# Male   6     Male          Diabetes   4653
#        7     Male      Hypertension   4633
#        8     Male            Asthma   4632
#        9     Male            Cancer   4625
#        10    Male         Arthritis   4622

# %% [markdown]
# #### Identifying whether different medical conditions correlate with blood types.

# %%
import pandas as pd
#create a contigency table
contingency_table = pd.crosstab(df['Blood Type'], df['Medical Condition'])
print(contingency_table)
#chi square
from scipy.stats import chi2_contingency
chi2, p, dof, expected = chi2_contingency(contingency_table)
print(f"Chi-Square Statistic: {chi2}")
print(f"P-value: {p}")
#pvalue is gretater than 0.05 no correlation
# Out:
# Medical Condition  Arthritis  Asthma  Cancer  Diabetes  Hypertension  Obesity
# Blood Type
# A+                      1116    1135    1185      1213          1128     1179
# A-                      1153    1173    1134      1167          1199     1143
# AB+                     1130    1189    1112      1173          1215     1128
# AB-                     1192    1134    1198      1139          1125     1157
# B+                      1201    1108    1196      1188          1103     1149
# B-                      1169    1119    1144      1151          1173     1188
# O+                      1198    1173    1108      1151          1157     1130
# O-                      1149    1154    1150      1122          1145     1157
# Chi-Square Statistic: 34.8201955981535
# P-value: 0.4767568949673894

# %% [markdown]
# #### Plotting a pie chart showing relation between medical condition and billing amount

# %%
 

import pandas as pd
import matplotlib.pyplot as plt

# %%
#grouping medical conditions based on bills(sum of bill pf each medical condition)
billing_per_condition = df.groupby('Medical Condition')['Billing Amount'].sum()
billing_per_condition
# Out:
# Medical Condition
# Arthritis       2.373291e+08
# Asthma          2.354598e+08
# Cancer          2.321679e+08
# Diabetes        2.385397e+08
# Hypertension    2.357207e+08
# Obesity         2.382149e+08
# Name: Billing Amount, dtype: float64

# %%
df['Billing Amount'].sum().round()
# Out:
# 1417432043.0

# %%
#plotting a pie chart 
plt.pie(billing_per_condition, labels=billing_per_condition.index, autopct='%1.1f%%', startangle=45, colors=['#ff9999','#66b3ff','#99ff99', '#ffcc99'])
plt.title('Total Billing Amount by Medical Condition')
plt.axis('equal')
plt.show()

# %% [markdown]
# #### Identifying the average cost of treatment for different conditions across various hospitals

# %%
##grouping medical condition and hospitals and then finding the mean
average_cost = df.groupby(['Medical Condition', 'Hospital'])['Billing Amount'].mean().reset_index()
average_cost
# Out:
#       Medical Condition                     Hospital  Billing Amount
# 0             Arthritis                   Abbott Inc    38052.041917
# 1             Arthritis                   Abbott Ltd    29877.586483
# 2             Arthritis              Abbott-Castillo    18397.742148
# 3             Arthritis                Abbott-Martin    48968.880890
# 4             Arthritis                  Acevedo LLC    23600.500940
# ...                 ...                          ...             ...
# 46179           Obesity      and Young, Spencer Byrd    10135.134397
# 46180           Obesity   and Young, Torres Figueroa    25126.238871
# 46181           Obesity   and Zhang Brooks, Hamilton    36765.362613
# 46182           Obesity  and Zhang Underwood, Martin    42984.547565
# 46183           Obesity           and Zimmerman Sons    32706.652625
#
# [46184 rows x 3 columns]

# %% [markdown]
# #### Identifying the distribution of medical conditions different between male and female patients.

# %%
#Visualization: A grouped bar chart showing the count of each medical condition for males and females.
grouped_data = df.groupby(['Medical Condition', 'Gender']).size().unstack()
grouped_data
# Out:
# Gender             Female  Male
# Medical Condition
# Arthritis            4686  4622
# Asthma               4553  4632
# Cancer               4602  4625
# Diabetes             4651  4653
# Hypertension         4612  4633
# Obesity              4622  4609

# %%
#plotting a bar graph 
grouped_data.plot(kind='bar', figsize=(10,6))
plt.title('Count of Medical Conditions by Gender')
plt.xlabel('Medical Condition')
plt.ylabel('Count')
plt.xticks(rotation=47)
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.tight_layout()

# %% [markdown]
# #### Identifying whether different age groups are affected by specific medical conditions.

# %%
#Visualization: A box plot or histogram displaying the age distribution for each medical condition.
#grouping data based on age and medical condition 
grouped = df.groupby(['Age', 'Medical Condition']).size().reset_index(name='Counts')
grouped
# Out:
#      Age Medical Condition  Counts
# 0     13         Arthritis       2
# 1     13            Asthma       3
# 2     13            Cancer       2
# 3     13      Hypertension       1
# 4     13           Obesity       6
# ..   ...               ...     ...
# 456   89            Asthma       1
# 457   89            Cancer       1
# 458   89          Diabetes       1
# 459   89      Hypertension       2
# 460   89           Obesity       1
#
# [461 rows x 3 columns]

# %%
plt.figure(figsize=(25, 15))
sns.barplot(data=grouped, x='Age', y='Counts', hue='Medical Condition')
plt.title('Counts of Medical Conditions by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Counts')
plt.legend(title='Medical Condition')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
